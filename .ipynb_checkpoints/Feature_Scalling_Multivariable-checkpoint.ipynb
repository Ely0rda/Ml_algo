# %% [markdown]
# # Feature scalling (Multi-variable)

# %%
import numpy as np
import matplotlib.pyplot as plt
from kobeni import *

# %% [markdown]
# ### Training set

# %%
x_train,y_train = load_data("./data/houses.txt")
x_features = ['size(sqft)','bedrooms','floors','age']
print(f" numrows : {x_train.shape[0]}")
print(f" numcols : {x_train.shape[1]}")
# Out:
#  numrows : 99
#  numcols : 4

# %% [markdown]
# ### Visualizing data

# %%
fig, axe = plt.subplots(1,4,constrained_layout=True, figsize=(12,3),sharey=True)
for i in range(len(axe)):
    axe[i].scatter(x_train[:,i],y_train)
    axe[i].set_xlabel(x_features[i])
axe[0].set_ylabel("Price (1000's)")
plt.show()

# %% [markdown]
# ## Gradient descent without feature scalling

# %%
w_i = np.zeros(x_train.shape[1])
b_i = 0
lr = Linear_reg()
w,b,J_history = lr.compute_gd(x_train,y_train,w_i,b_i,10,1e-7,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3528\936595974.py in <module>
#       1 w_i = np.zeros(x_train.shape[1])
#       2 b_i = 0
# ----> 3 lr = Linear_rg()
#       4 w,b,J_history = lr.compute_gd(x_train,y_train,w_i,b_i,10,1e-7,1)
#
# NameError: name 'Linear_rg' is not defined

# %% [markdown]
# ### Plotting

# %%
plt.plot(J_history)
plt.xlabel('Cost')
plt.ylabel('Number of iterations')
plt.title('Cost v number of iterations')
plt.show()

# %% [markdown]
# ## Gradient descent with feature scalling

# %% [markdown]
# ### z-score normalization
# **z-score normalization formula:**
# $$x^{(i)}_j = \dfrac{x^{(i)}_j - \mu_j}{\sigma_j} \tag{4}$$
# **µ𝑗** is the mean and **𝜎𝑗** is the standard deviation
# \begin{align}
# \mu_j &= \frac{1}{m} \sum_{i=0}^{m-1} x^{(i)}_j \tag{5}\\
# \sigma^2_j &= \frac{1}{m} \sum_{i=0}^{m-1} (x^{(i)}_j - \mu_j)^2  \tag{6}
# \end{align}

# %% [markdown]
# ### Calculating stdev

# %%
def comp_stdev(x):
    mu = comp_mean(x)
    m = x.shape[0]
    n = x.shape[1]
    sigma = np.zeros(n)
    for j in range(n):
        for i in range(m):
             sigma[j] += pow(x[i][j]-mu[j],2)/m
    return np.sqrt(sigma)

# %% [markdown]
# ### Calculating the mean

# %%
def comp_mean(x):
    m = x.shape[0]
    n = x.shape[1]
    mu = np.zeros(n)
    for j in range(n):
        for i in range(m):
            mu[j] += x[i][j]/m
    return mu

# %% [markdown]
# ### Implementing z_score normalization

# %%
#takes all your input features and normalize them
def zscore_norm(x):
    m = x.shape[0]
    n = x.shape[1]
    x_norm = np.zeros(x.shape)
    x_mu = comp_mean(x)
    x_sigma = comp_stdev(x)
    for i in range(m):
        for j in range(n):
            x_norm[i][j] = (x[i][j] - x_mu[j])/ x_sigma[j]
    return x_norm,x_mu,x_sigma

# %% [markdown]
# ### Normalizing the training data

# %%
x_norm,x_mu,x_sigma = zscore_norm(x_train)
print(f"mu = {x_mu}\nsigma = {x_sigma}")
print(f"Peak to Peak range by column in x_train PTP : {np.ptp(x_train,axis=0)}")
print(f"Peak to Peak range by column in x_train PTP : {np.ptp(x_norm,axis=0)}")
# Out:
# mu = [1.41837374e+03 2.71717172e+00 1.38383838e+00 3.83838384e+01]
# sigma = [411.61562893   0.65196523   0.48631932  25.77788069]
# Peak to Peak range by column in x_train PTP : [2.406e+03 4.000e+00 1.000e+00 9.500e+01]
# Peak to Peak range by column in x_train PTP : [5.8452591  6.13529646 2.05626214 3.68533012]

# %% [markdown]
# ### Runing gradient descent with feature scalling

# %%
w_norm,b_norm,J_history = compute_gd(x_norm,y_train,w_i,b_i,1000,1.0e-1,100)
# Out:
# w,b found by gradient descent: w: [110.56039756 -21.26715096 -32.70718139 -37.97015909], b: 363.16

# %% [markdown]
# ### Target vs predictions

# %%
m = x_norm.shape[0]
yp = compute_fwb(x_norm,w_norm,b_norm)

    # plot predictions and targets versus original features    
fig,ax=plt.subplots(1,4,figsize=(12, 3),sharey=True)
for i in range(len(ax)):
    ax[i].scatter(x_train[:,i],y_train, label = 'target')
    ax[i].set_xlabel(x_features[i])
    ax[i].scatter(x_train[:,i],yp,color="orange", label = 'predict')
ax[0].set_ylabel("Price"); ax[0].legend();
fig.suptitle("target versus prediction using z-score normalized model")
plt.show()
